# %%
# importing 
import pandas as pd
from sqlalchemy import create_engine

# %%
# Store CSV into DataFrame
streaming_data = "data/MoviesOnStreaming.csv"
streaming_data_df = pd.read_csv(streaming_data)

# %%
streaming_data_df.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#    Netflix  Hulu  Prime Video  Disney+                       Directors  \
# 0        1     0            0        0               Christopher Nolan
# 1        1     0            0        0  Lana Wachowski,Lilly Wachowski
# 2        1     0            0        0         Anthony Russo,Joe Russo
# 3        1     0            0        0                 Robert Zemeckis
# 4        1     0            1        0                    Sergio Leone
#
#                              Genres                       Country  \
# ...

# %%
streaming_data_df.count()
# Out:
# ID                 16744
# Title              16744
# Year               16744
# Age                 7354
# IMDb               16173
# Rotten Tomatoes     5158
# Netflix            16744
# Hulu               16744
# Prime Video        16744
# Disney+            16744
# Directors          16018
# Genres             16469
# Country            16309
# Language           16145
# Runtime            16152
# dtype: int64

# %%
# Dropping column name showed up in DF conflicting with PGADMIN DB.
streaming_data_df.drop(columns=['Disney+'],inplace = True)

# %%
streaming_na_df = streaming_data_df.dropna()

# %%
streaming_na_df.count()
# Out:
# ID                 3301
# Title              3301
# Year               3301
# Age                3301
# IMDb               3301
# Rotten Tomatoes    3301
# Netflix            3301
# Hulu               3301
# Prime Video        3301
# Directors          3301
# Genres             3301
# Country            3301
# Language           3301
# Runtime            3301
# dtype: int64

# %%
stm_us_df = streaming_na_df.loc[streaming_na_df["Country"] == "United States", :]

# %%
stm_us_df
# Out:
#           ID                              Title  Year  Age  IMDb  \
# 1          2                         The Matrix  1999  18+   8.7
# 2          3             Avengers: Infinity War  2018  13+   8.5
# 3          4                 Back to the Future  1985   7+   8.5
# 5          6  Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 7          8                   Django Unchained  2012  18+   8.4
# ...      ...                                ...   ...  ...   ...
# 16637  16638                 Inspector Gadget 2  2003  all   3.4
# 16643  16644                   Doug's 1st Movie  1999  all   5.0
# 16677  16678                      That Darn Cat  1997   7+   4.7
# 16687  16688                             Kazaam  1996   7+   3.0
# 16705  16706                   Meet the Deedles  1998   7+   4.1
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  \
# 1                 87%        1     0            0
# 2                 84%        1     0            0
# ...

# %%
stm_us_df.drop(columns=['Country'],inplace = True)
# Out:
# C:\Users\ashle\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Extracting % Rotten Tamatoes column
stm_us_df[stm_us_df.columns[5]] = stm_us_df[stm_us_df.columns[5]].replace('[%]', '', regex=True).astype(int)
# Out:
# C:\Users\ashle\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Below codes are commented, it ran successfully.
# Converting Netflix, Hulu and Prime Videio value (0 and 1) into boolean data type (True and False)
# Netflix 
#stm_us_df[stm_us_df.columns[6]] = stm_us_df[stm_us_df.columns[6]].replace('[1]',True, regex=True).astype(bool)
#Hulu
#stm_us_df[stm_us_df.columns[7]] = stm_us_df[stm_us_df.columns[7]].replace('[1]',True, regex=True).astype(bool)
# Prime Video
#stm_us_df[stm_us_df.columns[8]] = stm_us_df[stm_us_df.columns[8]].replace('[1]',True, regex=True).astype(bool)

# %%
stm_us_df.sort_values(by=['Title', 'Year'], ascending= True, inplace = True )
# Out:
# C:\Users\ashle\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Converting Upper case column name to lower case. 
stm_us_df.columns = map(str.lower, stm_us_df.columns)

# %%
# Removing space between column name 
stm_us_df = stm_us_df.rename(columns={"rotten tomatoes":"rotten_tomatoes", "prime video":"prime_video"})

# %%
#Final clean stream Data Frame and ready to load into pgadmin (SQL)
final_stream_df = stm_us_df.copy()

# %%
final_stream_df.head()
# Out:
#           id                                        title  year  age  imdb  \
# 6674    6675                                      1 Night  2017  13+   5.8
# 16442  16443  101 Dalmatians II: Patch's London Adventure  2003  all   5.8
# 5080    5081                                        11:55  2017  18+   4.9
# 1075    1076                                   13 Cameras  2015  18+   5.1
# 644      645                                      13 Sins  2014  18+   6.3
#
#        rotten_tomatoes  netflix  hulu  prime_video                 directors  \
# 6674                33        0     0            1               Minhal Baig
# 16442               67        0     0            0  Jim Kammerud,Brian Smith
# 5080               100        0     0            1     Ari Issler,Ben Snyder
# 1075                77        1     0            0            Victor Zarcoff
# 644                 65        1     0            0              Daniel Stamm
#
# ...

# %%
final_stream_df.dtypes
# Out:
# id                   int64
# title               object
# year                 int64
# age                 object
# imdb               float64
# rotten_tomatoes      int32
# netflix              int64
# hulu                 int64
# prime_video          int64
# directors           object
# genres              object
# language            object
# runtime            float64
# dtype: object

# %%
final_stream_df
# Out:
#           id                                        title  year  age  imdb  \
# 6674    6675                                      1 Night  2017  13+   5.8
# 16442  16443  101 Dalmatians II: Patch's London Adventure  2003  all   5.8
# 5080    5081                                        11:55  2017  18+   4.9
# 1075    1076                                   13 Cameras  2015  18+   5.1
# 644      645                                      13 Sins  2014  18+   6.3
# ...      ...                                          ...   ...  ...   ...
# 5970    5971                                   Zombeavers  2014  18+   4.8
# 3568    3569                                   Zombieland  2009  18+   7.6
# 2043    2044                                         Zoom  2006   7+   4.4
# 16225  16226                                     Zootopia  2016   7+   8.0
# 4529    4530                                       mid90s  2018  18+   7.4
#
#        rotten_tomatoes  netflix  hulu  prime_video  \
# ...

# %%
# Connecting to local database
netflix_connection_string = "admin1:12345@localhost:5432/netflixproject"
engine = create_engine(f'postgresql://{netflix_connection_string}')

# %%
# Pulling tables from database
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
# Below code worked and loaded successfully into pgAdmin Database table. 
final_stream_df.to_sql(name='netflix_stream', con=engine, if_exists='append', index=False)

# %%
# Go to pgadmin to see if all data has been loaded.
